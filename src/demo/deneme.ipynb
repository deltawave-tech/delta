# %%
import pandas as pd

# %%
data  = pd.read_csv("/Users/atabeyunlu/multi_agent_paper/runs_metadata/0611_1648_GO5/unique_ordered_molecules.csv")

# %%
data.tail()

# %%
database_mols = data[data["agent"] == "Database Agent"]
ai_mols = data[data["agent"] == "AI Expert"]
med_chem_mols = data[data["agent"] == "Medicinal Chemist"]

# %%
data.sort_values(by="qed", ascending=False).head(14).sort_values(by="docking_score", ascending=True)["smiles"][37]

# %%
from rdkit import Chem

smi = "Cc1cc(NC2=NC=C(F)C(N[C@H]3CC[C@@H](O)CC3)=N2)ccc1c1nnnn1[H]"

# %%
from rdkit import Chem

smi = "Cc1cc(NC2=NC=C(F)C(N[C@H]3CC[C@@H](O)CC3)=N2)ccc1c1nnnn1[H]"

Chem.MolToSmiles(Chem.MolFromSmiles(smi), isomericSmiles=False)

# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3-7-llm-only/unique_ordered_molecules.csv")

# %%
from rdkit import Chem

# Check validity of SMILES in med_chem dataframe
def check_smiles_validity(smiles):
    """Check if a SMILES string is valid using RDKit"""
    if pd.isna(smiles) or smiles == '':
        return False
    mol = Chem.MolFromSmiles(smiles)
    return mol is not None

# Apply validity check to all SMILES in med_chem dataframe
valid_smiles = data['smiles'].apply(check_smiles_validity)

# Count valid and invalid SMILES
valid_count = valid_smiles.sum()
invalid_count = (~valid_smiles).sum()
total_count = len(data)

print(f"SMILES Validity Check Results:")
print(f"Total molecules: {total_count}")
print(f"Valid SMILES: {valid_count}")
print(f"Invalid SMILES: {invalid_count}")
print(f"Validity rate: {valid_count/total_count*100:.2f}%")

# Show invalid SMILES if any exist
if invalid_count > 0:
    print(f"\nInvalid SMILES found:")
    invalid_smiles = data[~valid_smiles]['smiles'].tolist()
    for i, smiles in enumerate(invalid_smiles[:10]):  # Show first 10 invalid SMILES
        print(f"  {i+1}. {smiles}")
    if len(invalid_smiles) > 10:
        print(f"  ... and {len(invalid_smiles) - 10} more")

# Filter to only valid molecules
med_chem_valid = data[valid_smiles].copy()
print(f"\nFiltered dataframe with valid SMILES: {len(med_chem_valid)} molecules")

# %%
data.smiles.nunique()

# %%
akt1 = pd.read_csv("/Users/atabeyunlu/multi_agent_paper/activity_data.csv")
akt1_actives = akt1[akt1["pchembl_value"] >= 6]

# %%
def novelty(gen, train, n_jobs=1):
    gen_smiles_set = set(gen) - {None}
    train_set = set(train)
    return 0 if len(gen_smiles_set) == 0 else len(gen_smiles_set - train_set) / len(gen_smiles_set)

# %%
import torch
import numpy as np
def average_agg_tanimoto(stock_vecs, gen_vecs,
                         batch_size=5000, agg='max',
                         device='cpu', p=1, intdiv=False):
    """
    For each molecule in gen_vecs finds closest molecule in stock_vecs.
    Returns average tanimoto score for between these molecules

    Parameters:
        stock_vecs: numpy array <n_vectors x dim>
        gen_vecs: numpy array <n_vectors' x dim>
        agg: max or mean
        p: power for averaging: (mean x^p)^(1/p)
    """
    assert agg in ['max', 'mean'], "Can aggregate only max or mean"
    agg_tanimoto = np.zeros(len(gen_vecs))
    total = np.zeros(len(gen_vecs))
    for j in range(0, stock_vecs.shape[0], batch_size):
        x_stock = torch.tensor(stock_vecs[j:j + batch_size]).to(device).float()
        for i in range(0, gen_vecs.shape[0], batch_size):
            
            y_gen = torch.tensor(gen_vecs[i:i + batch_size]).to(device).float()
            y_gen = y_gen.transpose(0, 1)
            tp = torch.mm(x_stock, y_gen)
            jac = (tp / (x_stock.sum(1, keepdim=True) +
                         y_gen.sum(0, keepdim=True) - tp)).cpu().numpy()
            jac[np.isnan(jac)] = 1
            if p != 1:
                jac = jac**p
            if agg == 'max':
                agg_tanimoto[i:i + y_gen.shape[1]] = np.maximum(
                    agg_tanimoto[i:i + y_gen.shape[1]], jac.max(0))
            elif agg == 'mean':
                agg_tanimoto[i:i + y_gen.shape[1]] += jac.sum(0)
                total[i:i + y_gen.shape[1]] += jac.shape[0]
    if agg == 'mean':
        agg_tanimoto /= total
    if p != 1:
        agg_tanimoto = (agg_tanimoto)**(1/p)
    if intdiv:
        return agg_tanimoto
    else:
        return np.mean(agg_tanimoto), np.std(agg_tanimoto)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np

# Calculate Morgan fingerprints for akt1_actives canonical_smiles
akt1_actives_mols = [Chem.MolFromSmiles(smiles) for smiles in akt1_actives['canonical_smiles']]
akt1_actives_morgan_fps = []
for mol in akt1_actives_mols:
    if mol is not None:
        akt1_actives_morgan_fps.append(AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024))
    else:
        akt1_actives_morgan_fps.append(np.zeros(1024))

# Calculate Morgan fingerprints for med_chem smiles
med_chem_mols = [Chem.MolFromSmiles(smiles) for smiles in data['smiles']]
med_chem_morgan_fps = []
for mol in med_chem_mols:
    if mol is not None:
        med_chem_morgan_fps.append(AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024))
    else:
        med_chem_morgan_fps.append(np.zeros(1024))

print(f"AKT1 actives Morgan fingerprints calculated: {len(akt1_actives_morgan_fps)}")
print(f"Med chem Morgan fingerprints calculated: {len(med_chem_morgan_fps)}")

# %%
import numpy as np
sim_res = average_agg_tanimoto(np.array(akt1_actives_morgan_fps), np.array(med_chem_morgan_fps))
sim_res

# %%
import pandas as pd

# %%
import pandas as pd

data = pd.read_csv("/Users/atabeyunlu/multi_agent_paper/chembl_mols/chembl_mols_full.csv", sep=";", usecols=["ChEMBL ID", "Smiles"])

# %%
data.Smiles[:10].tolist()

# %%
from rdkit import Chem
import pandas as pd


def get_canonical_smiles(smiles_list):
    """
    Convert a list of SMILES strings to their canonical representations using RDKit.
    
    Args:
        smiles_list (list): List of SMILES strings
        
    Returns:
        list: List of canonical SMILES strings, None for invalid SMILES
    """
    canonical_smiles = []
    
    for smiles in smiles_list:
        if pd.isna(smiles) or smiles == '':
            canonical_smiles.append(None)
            continue
            
        mol = Chem.MolFromSmiles(smiles)
        if mol is not None:
            canonical_smiles.append(Chem.MolToSmiles(mol, canonical=True, isomericSmiles= False))
        else:
            canonical_smiles.append(None)
    
    return canonical_smiles

# %%
import os
import pandas as pd
from rdkit import Chem

# Paths to the CSV files
paths = [
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/single_multi_llm_runs/sonnet-3-7/unique_ordered_molecules.csv",
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/single_multi_llm_runs/sonnet-3-7-single-agent/unique_ordered_molecules.csv", 
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/single_multi_llm_runs/sonnet-3-7-llm-only/unique_ordered_molecules.csv"
]

# Make the reference data canonical
print("Making reference data canonical...")
data['canonical_smiles'] = get_canonical_smiles(data['Smiles'].tolist())
reference_smiles = set([s for s in data['canonical_smiles'] if s is not None])
print(f"Reference set size: {len(reference_smiles)}")

# %%
# Process each path
for i, path in enumerate(paths):
    if os.path.exists(path):
        print(f"\nProcessing path {i+1}: {path}")
        
        # Read the CSV
        df = pd.read_csv(path)
        
        # Make SMILES canonical
        # Filter for AI Expert and Medicinal Chemist agents
        df_filtered = df[df['agent'].isin(['LLM Drug Designer'])]
        df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered['smiles'].tolist())
        
        # Remove None values
        valid_smiles = [s for s in df_filtered['canonical_smiles'] if s is not None]
        
        # Calculate novelty
        novel_smiles = [s for s in valid_smiles if s not in reference_smiles]
        non_novel_smiles = [s for s in valid_smiles if s in reference_smiles]
        novelty_rate = len(novel_smiles) / len(valid_smiles) if valid_smiles else 0
        
        print(f"Total molecules: {len(df)}")
        print(f"Valid molecules: {len(valid_smiles)}")
        print(f"Novel molecules: {len(novel_smiles)}")
        print(f"Non-novel molecules: {non_novel_smiles}")
        print(f"Novelty rate: {novelty_rate:.3f}")
        
    else:
        print(f"Path not found: {path}")
# Out:
# Processing path 1: /Users/atabeyunlu/multi_agent_paper/runs_metadata/single_multi_llm_runs/sonnet-3-7/unique_ordered_molecules.csv
# Total molecules: 132
# Valid molecules: 0
# Novel molecules: 0
# Non-novel molecules: []
# Novelty rate: 0.000
#
# Processing path 2: /Users/atabeyunlu/multi_agent_paper/runs_metadata/single_multi_llm_runs/sonnet-3-7-single-agent/unique_ordered_molecules.csv
# Total molecules: 86
# Valid molecules: 0
# Novel molecules: 0
# Non-novel molecules: []
# Novelty rate: 0.000
#
# Processing path 3: /Users/atabeyunlu/multi_agent_paper/runs_metadata/single_multi_llm_runs/sonnet-3-7-llm-only/unique_ordered_molecules.csv
# Total molecules: 101
# Valid molecules: 101
# Novel molecules: 98
# Non-novel molecules: ['Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc(-c2cccnc2)n1', 'Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc(-c2cccnc2)n1', 'Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc(-c2cccnc2)n1']
# Novelty rate: 0.970

# %%
# Additional paths to process
additional_paths = [
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/gemini_runs",
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/gpt4.1_runs", 
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/o3_runs",
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs",
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged",
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged",
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3-7",
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3.7-genmol",
    "/Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-4"
]

# Process additional paths
print("\n" + "="*50)
print("PROCESSING ADDITIONAL PATHS")
print("="*50)

for i, base_path in enumerate(additional_paths):
    if os.path.exists(base_path):
        print(f"\nProcessing directory {i+1}: {base_path}")
        
        # Look for CSV files in the directory
        csv_files = []
        for root, dirs, files in os.walk(base_path):
            for file in files:
                if file.endswith('.csv') and 'unique_ordered_molecules' in file:
                    csv_files.append(os.path.join(root, file))
        
        if csv_files:
            print(f"Found {len(csv_files)} CSV files:")
            for csv_file in csv_files:
                print(f"  - {csv_file}")
                
                # Read the CSV
                try:
                    df = pd.read_csv(csv_file)
                    
                    # Check if 'smiles' column exists
                    smiles_col = 'smiles' if 'smiles' in df.columns else 'Smiles'
                    
                    # Make SMILES canonical
                    # Filter for AI Expert and Medicinal Chemist agents
                    df_filtered = df[df['agent'].isin(['AI Expert', 'Medicinal Chemist'])]
                    df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
                    
                    # Remove None values
                    valid_smiles = [s for s in df_filtered['canonical_smiles'] if s is not None]
                    
                    # Calculate novelty
                    novel_smiles = [s for s in valid_smiles if s not in reference_smiles]
                    novelty_rate = len(novel_smiles) / len(valid_smiles) if valid_smiles else 0
                    
                    print(f"    Total molecules: {len(df)}")
                    print(f"    Valid molecules: {len(valid_smiles)}")
                    print(f"    Novel molecules: {len(novel_smiles)}")
                    print(f"    Novelty rate: {novelty_rate:.3f}")
                    
                except Exception as e:
                    print(f"    Error processing {csv_file}: {e}")
        else:
            print("  No CSV files found with 'unique_ordered_molecules' in filename")
            
    else:
        print(f"Directory not found: {base_path}")

print("\n" + "="*50)
print("NOVELTY ANALYSIS COMPLETE")
print("="*50)
# Out:
# ==================================================
# PROCESSING ADDITIONAL PATHS
# ==================================================
#
# Processing directory 1: /Users/atabeyunlu/multi_agent_paper/runs_metadata/gemini_runs
# Found 4 CSV files:
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/gemini_runs/unique_ordered_molecules.csv
#     Total molecules: 99
#     Valid molecules: 69
#     Novel molecules: 63
#     Novelty rate: 0.913
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/gemini_runs/0614_1214_DA9_gemini_3/unique_ordered_molecules.csv
#     Total molecules: 35
#     Valid molecules: 25
#     Novel molecules: 19
#     Novelty rate: 0.760
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/gemini_runs/0616_1950_IM0_gemini_3/unique_ordered_molecules.csv
#     Total molecules: 33
#     Valid molecules: 23
#     Novel molecules: 23
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/gemini_runs/0615_1806_6S1_gemini_3/unique_ordered_molecules.csv
#     Total molecules: 31
#     Valid molecules: 21
#     Novel molecules: 21
#     Novelty rate: 1.000
#
# Processing directory 2: /Users/atabeyunlu/multi_agent_paper/runs_metadata/gpt4.1_runs
# Found 4 CSV files:
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/gpt4.1_runs/unique_ordered_molecules.csv
#     Total molecules: 71
#     Valid molecules: 41
#     Novel molecules: 41
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/gpt4.1_runs/0616_1857_0CF_gpt4.1_3/unique_ordered_molecules.csv
#     Total molecules: 19
#     Valid molecules: 9
#     Novel molecules: 9
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/gpt4.1_runs/0616_1924_WPS_gpt4.1_3/unique_ordered_molecules.csv
#     Total molecules: 22
#     Valid molecules: 12
#     Novel molecules: 12
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/gpt4.1_runs/0616_1910_GHA_gpt4.1_3/unique_ordered_molecules.csv
#     Total molecules: 30
#     Valid molecules: 20
#     Novel molecules: 20
#     Novelty rate: 1.000
#
# Processing directory 3: /Users/atabeyunlu/multi_agent_paper/runs_metadata/o3_runs
# Found 4 CSV files:
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/o3_runs/unique_ordered_molecules.csv
#     Total molecules: 101
#     Valid molecules: 71
#     Novel molecules: 71
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/o3_runs/0616_1737_5K6_o3_3/unique_ordered_molecules.csv
#     Total molecules: 37
#     Valid molecules: 27
#     Novel molecules: 27
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/o3_runs/0616_1617_Y81_o3_3/unique_ordered_molecules.csv
#     Total molecules: 35
#     Valid molecules: 24
#     Novel molecules: 24
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/o3_runs/0616_1826_VLM_o3_3/unique_ordered_molecules.csv
#     Total molecules: 29
#     Valid molecules: 20
#     Novel molecules: 20
#     Novelty rate: 1.000
#
# Processing directory 4: /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs
# Found 12 CSV files:
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0611_1648_GO5_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 42
#     Valid molecules: 32
#     Novel molecules: 32
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0624_1733_K68_sonnet-3.7_9/unique_ordered_molecules.csv
#     Total molecules: 71
#     Valid molecules: 65
#     Novel molecules: 65
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0624_1027_3X0_sonnet-3.7_5/unique_ordered_molecules.csv
#     Total molecules: 56
#     Valid molecules: 46
#     Novel molecules: 45
#     Novelty rate: 0.978
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0624_1713_ZSP_sonnet-3.7_9/unique_ordered_molecules.csv
#     Total molecules: 105
#     Valid molecules: 93
#     Novel molecules: 93
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0616_2232_GRR_sonnet-3.7_3/unique_ordered_molecules.csv
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:33] SMILES Parse Error: unclosed ring for input: 'C1CC=CC=C1C=C2C=CC(C3=CC(F)=CC=C3C(=O)N[C@H](CS(=O)2)=C(C)CCC=N)=N2'
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:33] SMILES Parse Error: unclosed ring for input: 'C1CC=CC=C1C=C2C=CC(C3=CC(F)=CC=C3C(=O)N[C@H](CS(=O)2)=C(C)CCC=N)=N2'
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:33] Can't kekulize mol.  Unkekulized atoms: 22 25 35
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:33] SMILES Parse Error: unclosed ring for input: 'CN1CCN(C2=CC=C3N=C(C4=CC=C(F)C=C4[NH1]C4=O)NC3=C2)CC1C'
# [21:16:33] SMILES Parse Error: unclosed ring for input: 'CCCOC(O)C1=CC=C(NC(=O)NC2=CC(F)=CC=C2NC(=O)N2CCN(C)CC2)'
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:33] Can't kekulize mol.  Unkekulized atoms: 2 3 11 12 13 28 29
# [21:16:33] SMILES Parse Error: unclosed ring for input: 'O=S(=O)(NC1=CC=C(c2nnco2)C(CN2C[C@H](O)CC2)=C1F)NCC2NC(C3CC3)=CC3=C(C)N=C(c4cnc(N)nc4)N3'
# [21:16:33] SMILES Parse Error: extra close parentheses while parsing: O=C(N1CCOCC1)N1CCC(C(=O)C2CC2)c2ccc3n(C)nc(c4cnc(N)nc4)c3c2F)CC1N
# [21:16:33] SMILES Parse Error: check for mistakes around position 61:
# [21:16:33] nc(c4cnc(N)nc4)c3c2F)CC1N
# [21:16:33] ~~~~~~~~~~~~~~~~~~~~^
# [21:16:33] SMILES Parse Error: Failed parsing SMILES 'O=C(N1CCOCC1)N1CCC(C(=O)C2CC2)c2ccc3n(C)nc(c4cnc(N)nc4)c3c2F)CC1N' for input: 'O=C(N1CCOCC1)N1CCC(C(=O)C2CC2)c2ccc3n(C)nc(c4cnc(N)nc4)c3c2F)CC1N'
# [21:16:33] SMILES Parse Error: extra close parentheses while parsing: O=C(N1CCOCC1)N1CCC(C(=O)C2CC2)c2ccc3n(C)nc(c4cnc(N)nc4)c3c2F)C[C@@H]1N
# [21:16:33] SMILES Parse Error: check for mistakes around position 61:
# [21:16:33] nc(c4cnc(N)nc4)c3c2F)C[C@@H]1N
# [21:16:33] ~~~~~~~~~~~~~~~~~~~~^
# [21:16:33] SMILES Parse Error: Failed parsing SMILES 'O=C(N1CCOCC1)N1CCC(C(=O)C2CC2)c2ccc3n(C)nc(c4cnc(N)nc4)c3c2F)C[C@@H]1N' for input: 'O=C(N1CCOCC1)N1CCC(C(=O)C2CC2)c2ccc3n(C)nc(c4cnc(N)nc4)c3c2F)C[C@@H]1N'
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
#     Total molecules: 40
#     Valid molecules: 30
#     Novel molecules: 30
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0624_1322_IX1_sonnet-3.7_7/unique_ordered_molecules.csv
#     Total molecules: 57
#     Valid molecules: 46
#     Novel molecules: 45
#     Novelty rate: 0.978
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0624_1330_KP1_sonnet-3.7_7/unique_ordered_molecules.csv
#     Total molecules: 73
#     Valid molecules: 63
#     Novel molecules: 63
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0624_1854_OFF_sonnet-3.7_9/unique_ordered_molecules.csv
#     Total molecules: 87
#     Valid molecules: 77
#     Novel molecules: 77
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0624_1302_UIL_sonnet-3.7_7/unique_ordered_molecules.csv
#     Total molecules: 81
#     Valid molecules: 71
#     Novel molecules: 71
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0624_1027_KM7_sonnet-3.7_5/unique_ordered_molecules.csv
#     Total molecules: 69
#     Valid molecules: 57
#     Novel molecules: 57
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0616_1530_KMB_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 50
#     Valid molecules: 40
#     Novel molecules: 40
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/iteration_runs/0624_1027_0OF_sonnet-3.7_5/unique_ordered_molecules.csv
#     Total molecules: 56
#     Valid molecules: 44
#     Novel molecules: 44
#     Novelty rate: 1.000
#
# Processing directory 5: /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged
# Found 21 CSV files:
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/unique_ordered_molecules.csv
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:33] Explicit valence for atom # 7 O, 3, is greater than permitted
# [21:16:33] SMILES Parse Error: unclosed ring for input: 'FC(F)(F)c1ccc(C(=O)N[C@@H]2CCN(C(=O)C)C[C@H]2NC(=O)c2noc3ccc(N4CCN(C)CC5)cc23)cc1'
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:33] Can't kekulize mol.  Unkekulized atoms: 21 22 23 24 25 26 28 29 31
# [21:16:33] Can't kekulize mol.  Unkekulized atoms: 19 20 21 22 23 24 26 27 29
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:33] Can't kekulize mol.  Unkekulized atoms: 19 20 21 22 23 24 25 26 28
# [21:16:33] Can't kekulize mol.  Unkekulized atoms: 17 18 25
# [21:16:33] Can't kekulize mol.  Unkekulized atoms: 17 18 30
# [21:16:33] SMILES Parse Error: extra open parentheses while parsing: Oc1nc2cc(F)ccc2n1C1CCN(Cc2ccc(-c3nc4cc(F)ccc4nc3-c3ccc(CN4CCN(C(=O)C5COC5)cc3)cc2)CC1
# [21:16:33] SMILES Parse Error: check for mistakes around position 23:
# [21:16:33] 1nc2cc(F)ccc2n1C1CCN(Cc2ccc(-c3nc4cc(F)cc
# [21:16:33] ~~~~~~~~~~~~~~~~~~~~^
# [21:16:33] SMILES Parse Error: Failed parsing SMILES 'Oc1nc2cc(F)ccc2n1C1CCN(Cc2ccc(-c3nc4cc(F)ccc4nc3-c3ccc(CN4CCN(C(=O)C5COC5)cc3)cc2)CC1' for input: 'Oc1nc2cc(F)ccc2n1C1CCN(Cc2ccc(-c3nc4cc(F)ccc4nc3-c3ccc(CN4CCN(C(=O)C5COC5)cc3)cc2)CC1'
# [21:16:34] SMILES Parse Error: syntax error while parsing: MOC1=CC=C(C2=NN=C(N)N=C2C3=CC=CC=C3)C(O)=C1C
# [21:16:34] SMILES Parse Error: check for mistakes around position 1:
# [21:16:34] MOC1=CC=C(C2=NN=C(N)N=C2C3=CC=CC=C3)C(O)=
# [21:16:34] ^
# [21:16:34] SMILES Parse Error: Failed parsing SMILES 'MOC1=CC=C(C2=NN=C(N)N=C2C3=CC=CC=C3)C(O)=C1C' for input: 'MOC1=CC=C(C2=NN=C(N)N=C2C3=CC=CC=C3)C(O)=C1C'
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:34] Can't kekulize mol.  Unkekulized atoms: 19 20 21 22 23 24 25 26 28
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:34] Can't kekulize mol.  Unkekulized atoms: 17 18 30
# [21:16:34] SMILES Parse Error: extra open parentheses while parsing: Oc1nc2cc(F)ccc2n1C1CCN(Cc2ccc(-c3nc4cc(F)ccc4nc3-c3ccc(CN4CCN(C(=O)C5COC5)cc3)cc2)CC1
# [21:16:34] SMILES Parse Error: check for mistakes around position 23:
# [21:16:34] 1nc2cc(F)ccc2n1C1CCN(Cc2ccc(-c3nc4cc(F)cc
# [21:16:34] ~~~~~~~~~~~~~~~~~~~~^
# [21:16:34] SMILES Parse Error: Failed parsing SMILES 'Oc1nc2cc(F)ccc2n1C1CCN(Cc2ccc(-c3nc4cc(F)ccc4nc3-c3ccc(CN4CCN(C(=O)C5COC5)cc3)cc2)CC1' for input: 'Oc1nc2cc(F)ccc2n1C1CCN(Cc2ccc(-c3nc4cc(F)ccc4nc3-c3ccc(CN4CCN(C(=O)C5COC5)cc3)cc2)CC1'
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:34] Can't kekulize mol.  Unkekulized atoms: 17 18 25
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:34] SMILES Parse Error: syntax error while parsing: MOC1=CC=C(C2=NN=C(N)N=C2C3=CC=CC=C3)C(O)=C1C
# [21:16:34] SMILES Parse Error: check for mistakes around position 1:
# [21:16:34] MOC1=CC=C(C2=NN=C(N)N=C2C3=CC=CC=C3)C(O)=
# [21:16:34] ^
# [21:16:34] SMILES Parse Error: Failed parsing SMILES 'MOC1=CC=C(C2=NN=C(N)N=C2C3=CC=CC=C3)C(O)=C1C' for input: 'MOC1=CC=C(C2=NN=C(N)N=C2C3=CC=CC=C3)C(O)=C1C'
#     Total molecules: 888
#     Valid molecules: 683
#     Novel molecules: 682
#     Novelty rate: 0.999
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_2215_GV4_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 34
#     Valid molecules: 24
#     Novel molecules: 24
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1553_SQR_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 46
#     Valid molecules: 36
#     Novel molecules: 36
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1123_J16_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 44
#     Valid molecules: 33
#     Novel molecules: 33
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_2346_5JY_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 50
#     Valid molecules: 40
#     Novel molecules: 40
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1547_7QG_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 49
#     Valid molecules: 37
#     Novel molecules: 37
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1736_LFZ_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 49
#     Valid molecules: 39
#     Novel molecules: 38
#     Novelty rate: 0.974
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1913_73S_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 39
#     Valid molecules: 29
#     Novel molecules: 29
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1935_6TH_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 34
#     Valid molecules: 24
#     Novel molecules: 24
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1402_RBU_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 42
#     Valid molecules: 31
#     Novel molecules: 31
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1537_OUH_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 47
#     Valid molecules: 37
#     Novel molecules: 37
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0619_0025_VXG_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 46
#     Valid molecules: 36
#     Novel molecules: 36
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1729_CRK_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 47
#     Valid molecules: 37
#     Novel molecules: 37
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1357_0GD_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 50
#     Valid molecules: 40
#     Novel molecules: 40
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1123_149_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 50
#     Valid molecules: 40
#     Novel molecules: 40
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_2055_NWG_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 43
#     Valid molecules: 32
#     Novel molecules: 32
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1339_MOQ_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 46
#     Valid molecules: 36
#     Novel molecules: 36
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1123_5HI_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 42
#     Valid molecules: 32
#     Novel molecules: 32
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_2252_2M0_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 46
#     Valid molecules: 36
#     Novel molecules: 36
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_2110_12Z_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 44
#     Valid molecules: 34
#     Novel molecules: 34
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_3_7_merged/0618_1752_Z5R_sonnet-3.7_3/unique_ordered_molecules.csv
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:34] SMILES Parse Error: unclosed ring for input: 'COC1=CC=C(C(C2)NC3=NC(N4CCC(C)CC4)=CN=C3S2)'
# [21:16:34] SMILES Parse Error: unclosed ring for input: 'COc1ccc(CC=C(Nc2ccc(Cl)cc2)N(C)C)'
# [21:16:34] SMILES Parse Error: extra open parentheses while parsing: CC1=NC=CC=C1C2=CC=CC(C(=O)NC3=CC=CC(Cl)=C3Cl
# [21:16:34] SMILES Parse Error: check for mistakes around position 21:
# [21:16:34] CC1=NC=CC=C1C2=CC=CC(C(=O)NC3=CC=CC(Cl)=C
# [21:16:34] ~~~~~~~~~~~~~~~~~~~~^
# [21:16:34] SMILES Parse Error: Failed parsing SMILES 'CC1=NC=CC=C1C2=CC=CC(C(=O)NC3=CC=CC(Cl)=C3Cl' for input: 'CC1=NC=CC=C1C2=CC=CC(C(=O)NC3=CC=CC(Cl)=C3Cl'
#     Total molecules: 40
#     Valid molecules: 30
#     Novel molecules: 30
#     Novelty rate: 1.000
#
# Processing directory 6: /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged
# Found 21 CSV files:
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/unique_ordered_molecules.csv
#     Total molecules: 1133
#     Valid molecules: 890
#     Novel molecules: 882
#     Novelty rate: 0.991
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_1942_A5F_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 41
#     Valid molecules: 31
#     Novel molecules: 30
#     Novelty rate: 0.968
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0612_2010_OUU_sonnet-4_3/unique_ordered_molecules.csv
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:34] SMILES Parse Error: unclosed ring for input: 'COC1=CC=C(C(C2)NC3=NC(N4CCC(C)CC4)=CN=C3S2)'
# [21:16:34] SMILES Parse Error: unclosed ring for input: 'COc1ccc(CC=C(Nc2ccc(Cl)cc2)N(C)C)'
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# [21:16:34] SMILES Parse Error: extra open parentheses while parsing: CC1=NC=CC=C1C2=CC=CC(C(=O)NC3=CC=CC(Cl)=C3Cl
# [21:16:34] SMILES Parse Error: check for mistakes around position 21:
# [21:16:34] CC1=NC=CC=C1C2=CC=CC(C(=O)NC3=CC=CC(Cl)=C
# [21:16:34] ~~~~~~~~~~~~~~~~~~~~^
# [21:16:34] SMILES Parse Error: Failed parsing SMILES 'CC1=NC=CC=C1C2=CC=CC(C(=O)NC3=CC=CC(Cl)=C3Cl' for input: 'CC1=NC=CC=C1C2=CC=CC(C(=O)NC3=CC=CC(Cl)=C3Cl'
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
#     Total molecules: 41
#     Valid molecules: 31
#     Novel molecules: 31
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_2122_SQ6_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 41
#     Valid molecules: 29
#     Novel molecules: 29
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_1833_G74_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 45
#     Valid molecules: 35
#     Novel molecules: 35
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_2312_4GK_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 43
#     Valid molecules: 33
#     Novel molecules: 33
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_2239_FA8_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 52
#     Valid molecules: 42
#     Novel molecules: 41
#     Novelty rate: 0.976
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0626_1627_NO6_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 42
#     Valid molecules: 32
#     Novel molecules: 31
#     Novelty rate: 0.969
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0616_1306_GNB_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 68
#     Valid molecules: 58
#     Novel molecules: 57
#     Novelty rate: 0.983
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_1833_S2J_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 61
#     Valid molecules: 51
#     Novel molecules: 50
#     Novelty rate: 0.980
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_1950_WGT_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 64
#     Valid molecules: 54
#     Novel molecules: 54
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0616_1316_KOC_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 43
#     Valid molecules: 33
#     Novel molecules: 33
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0616_1311_NSZ_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 48
#     Valid molecules: 38
#     Novel molecules: 38
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0613_1530_HYL_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 37
#     Valid molecules: 27
#     Novel molecules: 27
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_2209_DK9_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 41
#     Valid molecules: 31
#     Novel molecules: 31
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_2104_8Q5_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 44
#     Valid molecules: 33
#     Novel molecules: 32
#     Novelty rate: 0.970
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_2013_9CH_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 59
#     Valid molecules: 49
#     Novel molecules: 48
#     Novelty rate: 0.980
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0626_1627_H18_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 38
#     Valid molecules: 28
#     Novel molecules: 28
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_2134_T6A_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 44
#     Valid molecules: 34
#     Novel molecules: 34
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0612_2125_G1J_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 39
#     Valid molecules: 29
#     Novel molecules: 29
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet_4_merged/0617_1833_DXN_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 42
#     Valid molecules: 32
#     Novel molecules: 32
#     Novelty rate: 1.000
#
# Processing directory 7: /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3-7
# Found 4 CSV files:
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3-7/unique_ordered_molecules.csv
#     Total molecules: 132
#     Valid molecules: 102
#     Novel molecules: 102
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3-7/0611_1648_GO5_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 42
#     Valid molecules: 32
#     Novel molecules: 32
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3-7/0616_2232_GRR_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 40
#     Valid molecules: 30
#     Novel molecules: 30
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3-7/0616_1530_KMB_sonnet-3.7_3/unique_ordered_molecules.csv
#     Total molecules: 50
#     Valid molecules: 40
#     Novel molecules: 40
#     Novelty rate: 1.000
#
# Processing directory 8: /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3.7-genmol
# Found 4 CSV files:
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3.7-genmol/unique_ordered_molecules.csv
#     Total molecules: 28
#     Valid molecules: 18
#     Novel molecules: 18
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3.7-genmol/0623_2328_UVG_sonnet-3.7_5_genmol/unique_ordered_molecules.csv
#     Total molecules: 65
#     Valid molecules: 55
#     Novel molecules: 54
#     Novelty rate: 0.982
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3.7-genmol/0623_2328_GQO_sonnet-3.7_5_genmol/unique_ordered_molecules.csv
#     Total molecules: 58
#     Valid molecules: 48
#     Novel molecules: 48
#     Novelty rate: 1.000
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-3.7-genmol/0623_2328_AUY_sonnet-3.7_5_genmol/unique_ordered_molecules.csv
#     Total molecules: 65
#     Valid molecules: 60
#     Novel molecules: 60
#     Novelty rate: 1.000
#
# Processing directory 9: /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-4
# Found 5 CSV files:
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-4/unique_ordered_molecules.csv
#     Total molecules: 162
#     Valid molecules: 132
#     Novel molecules: 130
#     Novelty rate: 0.985
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-4/unique_ordered_molecules copy.csv
#     Total molecules: 280
#     Valid molecules: 220
#     Novel molecules: 218
#     Novelty rate: 0.991
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-4/0617_2239_FA8_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 52
#     Valid molecules: 42
#     Novel molecules: 41
#     Novelty rate: 0.976
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-4/0616_1306_GNB_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 68
#     Valid molecules: 58
#     Novel molecules: 57
#     Novelty rate: 0.983
#   - /Users/atabeyunlu/multi_agent_paper/runs_metadata/sonnet-4/0617_1833_DXN_sonnet-4_3/unique_ordered_molecules.csv
#     Total molecules: 42
#     Valid molecules: 32
#     Novel molecules: 32
#     Novelty rate: 1.000
#
# ==================================================
# NOVELTY ANALYSIS COMPLETE
# ==================================================
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())
# /var/folders/73/tdfwvg897wx_q7g2sc9xb5c00000gn/T/ipykernel_27269/635601622.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['canonical_smiles'] = get_canonical_smiles(df_filtered[smiles_col].tolist())

# %%
from molbloom import buy
buy('O=CN1C(C2CCCC2)C(=O)N1CC=C3C=C(NC4CC(N5CCC6=CC=C(O)C(F)=C6C5=O)CC4)C=C3O',catalog="zinc20", canonicalize=True)
# Out:
# False
